# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
x = np.array((3,13,19,31,38,45,58,65,71,88))

# %%
y = np.array((11,16,24,37,41,58,56,78,81,95))

# %%
z = np.array((81,80,79,63,54,32,29,26,18,14))

# %%
x,y,z
# Out:
# (array([ 3, 13, 19, 31, 38, 45, 58, 65, 71, 88]),
#  array([11, 16, 24, 37, 41, 58, 56, 78, 81, 95]),
#  array([81, 80, 79, 63, 54, 32, 29, 26, 18, 14]))

# %%
plt.title("My first plot")
plt.xlabel("First value")
plt.ylabel("Second value")
plt.grid()
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.xticks(range(0, 101, 10))
plt.yticks(range(0, 101, 10))
plt.plot(x, y, color = 'red', marker = 'o', ls = ':', mfc = 'blue')
plt.plot(x, z, color = 'green')

# %%
plt.title("My first plot")
plt.xlabel("First value")
plt.ylabel("Second value")
plt.grid()
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.xticks(range(0, 101, 10))
plt.yticks(range(0, 101, 10))
plt.plot(x, y, color = 'red', label = '2023')
plt.plot(x, z, color = 'green', label = '2022')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
plt.subplot(121)
plt.plot(x,y)
plt.subplot(122)
plt.plot(x,z)

# %%
plt.figure(figsize = (16,9,))
plt.title("My first plot")
plt.grid()
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.xticks(range(0, 101, 10))
plt.yticks(range(0, 101, 10))
plt.plot(x, z, lw = 5, marker = 'o', ms = 20, mfc = 'y')
plt.savefig("plot.png")

# %%
plt.figure(figsize = (16,9,))
plt.title("My first plot")
plt.grid()
plt.xlim(0, 100)
plt.ylim(0, 100)
plt.xticks(range(0, 101, 10))
plt.yticks(range(0, 101, 10))
plt.scatter(x, y)

# %%
java = np.array((43,78,65,69,63,82,47,77,85,50,66,81))

# %%
python = np.array((46,81,62,66,69,77,41,75,88,43,65,83))

# %%
plt.title("Result")
plt.xlabel("Java Marks")
plt.ylabel("Python marks")
plt.grid()
plt.scatter(java, python)

# %% [markdown]
# ### Bar plot

# %%
enrollment = [104,122,256,178,126,180]

# %%
courses = ['C', "Java", "Python", "R", "PHP", "JavaScript"]

# %%
plt.xlabel("Courses")
plt.ylabel("Enrolled Students")
plt.bar(courses, enrollment, color = 'green')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.ylabel("Courses")
plt.xlabel("Enrolled Students")
plt.barh(courses, enrollment, color = 'green')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### Pie chart

# %%
plt.figure(figsize = (10, 10,),)
plt.pie(enrollment, labels = courses, autopct = "%2.2f", shadow = True)
plt.plot()
# Out:
# []

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ### Histogram

# %%
marks = np.array([67,56,45,61,93,72,65,58,65,49,68,62])

# %%
plt.title("Frequency plot of marks")
plt.xlabel("Range of marks")
plt.ylabel("Count")
plt.grid()
plt.xticks(range(0, 101, 10))
# plt.yticks(range(0, 10, 2))
plt.hist(marks, bins = range(0, 101, 10), color = 'lightgreen');

# %% [markdown]
# ### Box plot

# %%
plt.boxplot([22,23,11,51,42,86,44,18,81,84,39,37,68,99,95,64,42,70]);

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# #### Regression

# %%
df = pd.read_csv("Salary_Data.csv")
df.shape
# Out:
# (30, 2)

# %%
plt.scatter(df["YearsExperience"], df["Salary"]);
plt.plot();

# %% [markdown]
# #### Sepearate the input and output data

# %%
x = df["YearsExperience"].values
y = df["Salary"]

# %%
x,y
# Out:
# (array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#          4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#          7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5]),
#  0      39343.0
#  1      46205.0
#  2      37731.0
#  3      43525.0
#  4      39891.0
#  5      56642.0
#  6      60150.0
#  7      54445.0
#  8      64445.0
#  9      57189.0
#  10     63218.0
#  11     55794.0
#  12     56957.0
#  13     57081.0
#  14     61111.0
#  15     67938.0
#  16     66029.0
#  17     83088.0
#  18     81363.0
#  19     93940.0
#  20     91738.0
#  21     98273.0
#  22    101302.0
#  23    113812.0
#  24    109431.0
#  25    105582.0
#  26    116969.0
#  27    112635.0
#  28    122391.0
#  29    121872.0
#  Name: Salary, dtype: float64)

# %%
x = x.reshape(-1, 1)

# %% [markdown]
# #### Import linear regression class

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Create the object of linear regression

# %%
regressor = LinearRegression()

# %% [markdown]
# #### Train the algorithm

# %%
regressor.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Predict on unseen data

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[20]])
# Out:
# array([214791.44662777])

# %%
regressor.predict([[25]])
# Out:
# array([262041.25823505])

# %%
regressor.score(x, y)
# Out:
# 0.9569566641435086
